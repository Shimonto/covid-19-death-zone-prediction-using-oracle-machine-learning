# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import preprocessing, svm
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
from sklearn import tree

# %%
#busra
df= pd.read_csv('/content/drive/MyDrive/cse464_project/s2_g3_1.csv')
#ayshee
#df= pd.read_csv('/content/drive/MyDrive/464/s2_g3_1.csv')
#df

# %%
x=df.iloc[:,:-1]
x
# Out:
#          DAYY  FIRST_DOSE_VACCINE_NUMBER  ...  CONFIRMED_CASE  DEATH_CASE
# 0    20201118                          0  ...            2111          21
# 1    20201121                          0  ...            1847          28
# 2    20201124                          0  ...            2230          32
# 3    20201127                          0  ...            2273          20
# 4    20201201                          0  ...            2293          31
# ..        ...                        ...  ...             ...         ...
# 621  20211017                     428016  ...             314          16
# 622  20211018                     363618  ...             339          10
# 623  20211019                     330760  ...             469           7
# 624  20211021                     392214  ...             243          10
# 625  20211023                     335106  ...             278           9
#
# [626 rows x 6 columns]

# %%
y=df.iloc[:,6]
y
# Out:
# 0             SAFE
# 1             SAFE
# 2      SEMI DANGER
# 3             SAFE
# 4      SEMI DANGER
#           ...
# 621           SAFE
# 622           SAFE
# 623           SAFE
# 624           SAFE
# 625           SAFE
# Name: DEATH_ZONE, Length: 626, dtype: object

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x.values,y.values,test_size=0.4)

# %% [markdown]
# decision tree

# %%
dt= tree.DecisionTreeClassifier()

# %%
dt=dt.fit(x_train, y_train)
pred_from_testset =dt.predict(x_test)
print(pred_from_testset)
# Out:
# ['SAFE' 'SEMI DANGER' 'SAFE' 'SEMI DANGER' 'DANGER' 'SAFE' 'SEMI DANGER'
#  'SEMI DANGER' 'SAFE' 'SEMI DANGER' 'SAFE' 'DANGER' 'DANGER' 'SEMI DANGER'
#  'SEMI DANGER' 'SAFE' 'DANGER' 'DANGER' 'SEMI DANGER' 'SAFE' 'SEMI DANGER'
#  'DANGER' 'SEMI DANGER' 'SEMI DANGER' 'SAFE' 'SEMI DANGER' 'SEMI DANGER'
#  'SAFE' 'SAFE' 'SEMI DANGER' 'SAFE' 'SEMI DANGER' 'SAFE' 'SEMI DANGER'
#  'DANGER' 'SEMI DANGER' 'SAFE' 'DANGER' 'SAFE' 'SAFE' 'SEMI DANGER' 'SAFE'
#  'SAFE' 'SEMI DANGER' 'SEMI DANGER' 'SAFE' 'SAFE' 'DANGER' 'SAFE' 'SAFE'
#  'SEMI DANGER' 'SEMI DANGER' 'SAFE' 'SAFE' 'SEMI DANGER' 'SEMI DANGER'
#  'DANGER' 'SAFE' 'SAFE' 'SEMI DANGER' 'SAFE' 'SAFE' 'SAFE' 'SEMI DANGER'
#  'SEMI DANGER' 'SAFE' 'SAFE' 'DANGER' 'SAFE' 'SEMI DANGER' 'SEMI DANGER'
#  'DANGER' 'SEMI DANGER' 'SEMI DANGER' 'SAFE' 'SEMI DANGER' 'SAFE' 'SAFE'
#  'SAFE' 'SAFE' 'SEMI DANGER' 'SAFE' 'DANGER' 'SEMI DANGER' 'SEMI DANGER'
#  'SEMI DANGER' 'SAFE' 'SAFE' 'DANGER' 'SAFE' 'SEMI DANGER' 'SEMI DANGER'
#  'SEMI DANGER' 'SAFE' 'SAFE' 'SAFE' 'SEMI DANGER' 'SAFE' 'SEMI DANGER'
#  'SAFE' 'SAFE' 'SAFE' 'DANGER' 'SAFE' 'SEMI DANGER' 'SEMI DANGER'
#  'SEMI DANGER' 'SAFE' 'SEMI DANGER' 'SAFE' 'SAFE' 'SEMI DANGER'
#  'SEMI DANGER' 'SEMI DANGER' 'DANGER' 'SEMI DANGER' 'SAFE' 'SEMI DANGER'
#  'SEMI DANGER' 'SEMI DANGER' 'SAFE' 'SAFE' 'SAFE' 'SAFE' 'SAFE'
#  'SEMI DANGER' 'SEMI DANGER' 'SEMI DANGER' 'SEMI DANGER' 'SAFE'
#  'SEMI DANGER' 'SAFE' 'SAFE' 'SEMI DANGER' 'SEMI DANGER' 'SAFE' 'SAFE'
#  'SEMI DANGER' 'SEMI DANGER' 'SAFE' 'SAFE' 'SEMI DANGER' 'SAFE'
#  'SEMI DANGER' 'SEMI DANGER' 'SAFE' 'DANGER' 'SEMI DANGER' 'SAFE' 'SAFE'
#  'SEMI DANGER' 'SAFE' 'SEMI DANGER' 'SEMI DANGER' 'SAFE' 'SEMI DANGER'
#  'DANGER' 'SEMI DANGER' 'SEMI DANGER' 'SAFE' 'SAFE' 'SEMI DANGER'
#  'SEMI DANGER' 'SAFE' 'SAFE' 'SEMI DANGER' 'SEMI DANGER' 'SAFE'
#  'SEMI DANGER' 'SAFE' 'SAFE' 'SAFE' 'DANGER' 'SAFE' 'SAFE' 'SAFE'
#  'SEMI DANGER' 'SAFE' 'SAFE' 'DANGER' 'SAFE' 'SEMI DANGER' 'SAFE' 'DANGER'
#  'SAFE' 'SEMI DANGER' 'SEMI DANGER' 'SEMI DANGER' 'SAFE' 'SEMI DANGER'
#  'SAFE' 'SEMI DANGER' 'DANGER' 'SEMI DANGER' 'SAFE' 'SAFE' 'SAFE' 'SAFE'
#  'DANGER' 'SEMI DANGER' 'SEMI DANGER' 'SEMI DANGER' 'SEMI DANGER' 'SAFE'
#  'SEMI DANGER' 'DANGER' 'SAFE' 'SAFE' 'SEMI DANGER' 'SAFE' 'SAFE' 'DANGER'
#  'SEMI DANGER' 'SAFE' 'SEMI DANGER' 'SAFE' 'SEMI DANGER' 'SAFE' 'SAFE'
#  'SEMI DANGER' 'SAFE' 'DANGER' 'SEMI DANGER' 'SEMI DANGER' 'SEMI DANGER'
#  'SEMI DANGER' 'DANGER' 'SEMI DANGER' 'SEMI DANGER' 'SAFE' 'DANGER'
#  'SEMI DANGER' 'SAFE' 'SAFE' 'SAFE' 'SAFE' 'SEMI DANGER' 'SAFE' 'SAFE'
#  'SEMI DANGER' 'DANGER' 'SAFE' 'SAFE' 'SEMI DANGER' 'SEMI DANGER'
#  'SEMI DANGER' 'SEMI DANGER' 'SEMI DANGER' 'DANGER' 'SAFE' 'SEMI DANGER']

# %%
user_prediction=dt.predict([[20210410,5440,0,26085,5370,25]])
user_prediction
# Out:
# array(['SAFE'], dtype=object)

# %%
score_dt=dt.score(x_test,y_test)
score_dt=score_dt*100
score_dt
# Out:
# 100.0

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,pred_from_testset)
cm
# Out:
# array([[ 30,   0,   0],
#        [  0, 112,   0],
#        [  0,   0, 109]])

# %% [markdown]
# random forest

# %%
from sklearn.ensemble import RandomForestClassifier
ran_df = RandomForestClassifier(n_estimators = 100) 
ran_df=ran_df.fit(x_train, y_train)
pred_from_testset_ran_df =ran_df.predict(x_test)
print(pred_from_testset_ran_df)
# Out:
# ['SAFE' 'SEMI DANGER' 'SAFE' 'SEMI DANGER' 'DANGER' 'SAFE' 'SEMI DANGER'
#  'SEMI DANGER' 'SAFE' 'SEMI DANGER' 'SAFE' 'DANGER' 'DANGER' 'SEMI DANGER'
#  'SEMI DANGER' 'SAFE' 'DANGER' 'DANGER' 'SEMI DANGER' 'SAFE' 'SEMI DANGER'
#  'DANGER' 'SEMI DANGER' 'SEMI DANGER' 'SAFE' 'SEMI DANGER' 'SEMI DANGER'
#  'SAFE' 'SAFE' 'SEMI DANGER' 'SAFE' 'SEMI DANGER' 'SAFE' 'SEMI DANGER'
#  'DANGER' 'SEMI DANGER' 'SAFE' 'DANGER' 'SAFE' 'SAFE' 'SEMI DANGER' 'SAFE'
#  'SAFE' 'SEMI DANGER' 'SEMI DANGER' 'SAFE' 'SAFE' 'DANGER' 'SAFE' 'SAFE'
#  'SEMI DANGER' 'SEMI DANGER' 'SAFE' 'SAFE' 'SEMI DANGER' 'SEMI DANGER'
#  'DANGER' 'SAFE' 'SAFE' 'SEMI DANGER' 'SAFE' 'SAFE' 'SAFE' 'SEMI DANGER'
#  'SEMI DANGER' 'SAFE' 'SAFE' 'DANGER' 'SAFE' 'SEMI DANGER' 'SEMI DANGER'
#  'DANGER' 'SEMI DANGER' 'SEMI DANGER' 'SAFE' 'SEMI DANGER' 'SAFE' 'SAFE'
#  'SAFE' 'SAFE' 'SEMI DANGER' 'SAFE' 'DANGER' 'SEMI DANGER' 'SEMI DANGER'
#  'SEMI DANGER' 'SAFE' 'SAFE' 'DANGER' 'SAFE' 'SEMI DANGER' 'SEMI DANGER'
#  'SEMI DANGER' 'SAFE' 'SAFE' 'SAFE' 'SEMI DANGER' 'SAFE' 'SEMI DANGER'
#  'SAFE' 'SAFE' 'SAFE' 'DANGER' 'SAFE' 'SEMI DANGER' 'SEMI DANGER'
#  'SEMI DANGER' 'SAFE' 'SEMI DANGER' 'SAFE' 'SAFE' 'SEMI DANGER'
#  'SEMI DANGER' 'SEMI DANGER' 'DANGER' 'SEMI DANGER' 'SAFE' 'SEMI DANGER'
#  'SEMI DANGER' 'SEMI DANGER' 'SAFE' 'SAFE' 'SAFE' 'SAFE' 'SAFE'
#  'SEMI DANGER' 'SEMI DANGER' 'SEMI DANGER' 'SEMI DANGER' 'SAFE'
#  'SEMI DANGER' 'SAFE' 'SAFE' 'SEMI DANGER' 'SEMI DANGER' 'SAFE' 'SAFE'
#  'SEMI DANGER' 'SEMI DANGER' 'SAFE' 'SAFE' 'SEMI DANGER' 'SAFE'
#  'SEMI DANGER' 'SEMI DANGER' 'SAFE' 'DANGER' 'SEMI DANGER' 'SAFE' 'SAFE'
#  'SEMI DANGER' 'SAFE' 'SEMI DANGER' 'SEMI DANGER' 'SAFE' 'SEMI DANGER'
#  'DANGER' 'SEMI DANGER' 'SEMI DANGER' 'SAFE' 'SAFE' 'SEMI DANGER'
#  'SEMI DANGER' 'SAFE' 'SAFE' 'SEMI DANGER' 'SEMI DANGER' 'SAFE'
#  'SEMI DANGER' 'SAFE' 'SAFE' 'SAFE' 'DANGER' 'SAFE' 'SAFE' 'SAFE'
#  'SEMI DANGER' 'SAFE' 'SAFE' 'DANGER' 'SAFE' 'SEMI DANGER' 'SAFE' 'DANGER'
#  'SAFE' 'SEMI DANGER' 'SEMI DANGER' 'SEMI DANGER' 'SAFE' 'SEMI DANGER'
#  'SAFE' 'SEMI DANGER' 'DANGER' 'SEMI DANGER' 'SAFE' 'SAFE' 'SAFE' 'SAFE'
#  'DANGER' 'SEMI DANGER' 'SEMI DANGER' 'SEMI DANGER' 'SEMI DANGER' 'SAFE'
#  'SEMI DANGER' 'DANGER' 'SAFE' 'SAFE' 'SEMI DANGER' 'SAFE' 'SAFE' 'DANGER'
#  'SEMI DANGER' 'SAFE' 'SEMI DANGER' 'SAFE' 'SEMI DANGER' 'SAFE' 'SAFE'
#  'SEMI DANGER' 'SAFE' 'DANGER' 'SEMI DANGER' 'SEMI DANGER' 'SEMI DANGER'
#  'SEMI DANGER' 'DANGER' 'SEMI DANGER' 'SEMI DANGER' 'SAFE' 'DANGER'
#  'SEMI DANGER' 'SAFE' 'SAFE' 'SAFE' 'SAFE' 'SEMI DANGER' 'SAFE' 'SAFE'
#  'SEMI DANGER' 'DANGER' 'SAFE' 'SAFE' 'SEMI DANGER' 'SEMI DANGER'
#  'SEMI DANGER' 'SEMI DANGER' 'SEMI DANGER' 'DANGER' 'SAFE' 'SEMI DANGER']

# %%
user_prediction=ran_df.predict([[20210410,5230,0,65085,5370,35]])
user_prediction
# Out:
# array(['SEMI DANGER'], dtype=object)

# %%
score_ran_df=ran_df.score(x_test,y_test)
score_ran_df=score_ran_df*100
score_ran_df
# Out:
# 100.0

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,pred_from_testset_ran_df)
cm
# Out:
# array([[ 30,   0,   0],
#        [  0, 112,   0],
#        [  0,   0, 109]])

# %% [markdown]
# linear regression

# %%
df_reg= pd.read_csv('/content/drive/MyDrive/cse464_project/for_regression.csv')
df_reg
# Out:
#          DAYY  FIRST_DOSE_VACCINE_NUMBER  ...  CONFIRMED_CASE  DEATH_CASE
# 0    20210408                      14804  ...            6854          74
# 1    20210410                      19943  ...            5343          77
# 2    20210411                      23657  ...            5819          78
# 3    20210412                      22456  ...            7201          83
# 4    20210413                      26750  ...            6028          69
# ..        ...                        ...  ...             ...         ...
# 621  20210121                          0  ...             584          16
# 622  20210124                          0  ...             473          20
# 623  20210129                          0  ...             454           7
# 624  20210202                          0  ...             525          12
# 625  20210205                          0  ...             435           7
#
# [626 rows x 6 columns]

# %%
df_reg.head()
# Out:
#        DAYY  FIRST_DOSE_VACCINE_NUMBER  ...  CONFIRMED_CASE  DEATH_CASE
# 0  20210408                      14804  ...            6854          74
# 1  20210410                      19943  ...            5343          77
# 2  20210411                      23657  ...            5819          78
# 3  20210412                      22456  ...            7201          83
# 4  20210413                      26750  ...            6028          69
#
# [5 rows x 6 columns]

# %%
x=df_reg.iloc[:,:-1]
x
# Out:
#          DAYY  FIRST_DOSE_VACCINE_NUMBER  ...  LAB_TEST  CONFIRMED_CASE
# 0    20210408                      14804  ...     33193            6854
# 1    20210410                      19943  ...     26077            5343
# 2    20210411                      23657  ...     29376            5819
# 3    20210412                      22456  ...     34968            7201
# 4    20210413                      26750  ...     32955            6028
# ..        ...                        ...  ...       ...             ...
# 621  20210121                          0  ...     14761             584
# 622  20210124                          0  ...     14169             473
# 623  20210129                          0  ...     12075             454
# 624  20210202                          0  ...     14452             525
# 625  20210205                          0  ...     15566             435
#
# [626 rows x 5 columns]

# %%
y=df_reg.iloc[:,5]
y
# Out:
# 0      74
# 1      77
# 2      78
# 3      83
# 4      69
#        ..
# 621    16
# 622    20
# 623     7
# 624    12
# 625     7
# Name: DEATH_CASE, Length: 626, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x.values, y.values, test_size=0.5, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg=reg.fit(x_train, y_train)

# %%
y_pred = reg.predict(x_test)
print(y_pred)
# Out:
# [ 2.88169864e+01  4.96847255e+01  3.36081678e+01  4.50639830e+01
#   3.37665991e+01  2.04432946e+02  6.31815846e+00  2.09479884e+01
#   1.52064862e+01 -4.28659336e+00  1.48508941e+01  1.79727195e+01
#   1.62716364e+01  7.43836394e+01  6.08698083e+01  4.09722829e+01
#  -3.38867468e+00  1.87711003e+01  4.79304064e+01  3.53152809e+01
#   1.82500183e+01  1.15690185e+01  7.28571740e+01  2.80640876e+01
#   2.31719607e+01  1.32024429e+01 -5.15458450e+00  3.70871836e+01
#   1.53961738e+02  1.67266427e+01  1.41504836e+01  2.46205640e+01
#   4.03855965e+01  1.23461064e+01  4.80819532e+01  2.13565035e+01
#   8.18104177e+01 -4.35503280e+00  1.76081514e+02  1.22411284e+01
#   4.24225024e+01  1.26813843e+02  2.49823802e+01  4.18864752e+01
#   9.27577507e+01  1.95633254e+02  2.27648420e+01  6.40145637e+01
#   3.77717031e+01  6.44133179e+01  3.90691284e+01  3.07129048e+01
#   3.03763480e+01  1.30986695e+01  3.63286442e+01  3.66364515e+01
#   3.12792724e+00  2.42294119e+01  1.92640725e+01  1.72240077e+01
#   1.01450990e+01  4.91005843e+01  1.63702274e+02  2.21567261e+01
#   4.06748779e+01  2.58674753e+02  1.13185221e+01  1.71553725e+01
#   1.30159365e+02  1.23053328e+02  3.28167428e+01  1.89809608e+01
#   3.97373253e+01  4.37890101e+01  4.08375339e+01  2.21567028e+02
#   1.88186848e+01  1.03972283e+02  2.81109239e+01  4.63992009e+01
#   7.07940986e+01  1.27791851e+01  3.26979970e+01  1.64512038e+01
#   1.04411949e+01  1.75344242e+01  6.74761692e+01  3.95445125e+01
#   2.63764032e+01  1.50752750e+01  3.93550272e+01  2.08181485e+02
#   2.95911149e+01 -7.58544856e+00  2.53783931e+01  3.89521344e+01
#   2.49075853e+01  2.13015835e+02  2.02026890e+02  3.99518229e+01
#   2.50984071e+01  2.66744312e+01  3.56210217e+01  4.78471053e+01
#  -4.71439790e+00  4.15086313e+01  4.19131657e+01 -2.26997828e+01
#   8.96658561e+01  1.07027414e+02  3.93797248e+01  3.75884298e+01
#   1.35882582e+01  2.64734742e+01  8.20585788e+00  4.06966047e+01
#   1.49618785e+02  3.96205306e+01  1.61624627e+01  1.60655557e+01
#   2.70386461e+01  1.96255045e+02  3.39326310e+01  1.46479413e+01
#  -7.03676687e-01  1.20488816e+02  5.03462794e+01  1.10704112e+02
#   3.31221785e+01  1.66356464e+01  3.26091846e+01  2.10227779e+01
#   7.90476005e+01  6.54235696e+01  2.13270951e+01  1.02345669e+01
#   4.42300243e+01  2.33230763e+01  3.92063226e+01  4.39815624e+01
#   5.52109021e+01  3.76454399e+01  7.29500155e+01  5.98119701e+01
#  -3.86484624e-02]

# %%
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df
# Out:
#      Actual  Predicted
# 0        35  28.816986
# 1        44  49.684726
# 2        38  33.608168
# 3        50  45.063983
# 4        32  33.766599
# ..      ...        ...
# 308      39  55.210902
# 309      41  37.645440
# 310      35  72.950016
# 311      38  59.811970
# 312       9  -0.038648
#
# [313 rows x 2 columns]

# %%
user_prediction=reg.predict([[20210411,23657,165691,29376,5819]])
user_prediction
# Out:
# array([106.72612026])

# %%
score_reg=reg.score(x_test,y_test)
score_reg=score_reg*100
score_reg
# Out:
# 86.41129182198848

# %%
import math 
from sklearn.metrics import mean_squared_error
mean_squad_error = mean_squared_error(y_test, y_pred)

root_mean_squad_error = math.sqrt(mean_squad_error)

print(root_mean_squad_error)
# Out:
# 20.755565161048825

# %%
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 12.2477963009816
# Mean Squared Error: 430.79348515454376
# Root Mean Squared Error: 20.755565161048825

# %%
accuracy=[]
accuracy.append(score_ran_df)
accuracy.append(score_reg)

accuracy
# Out:
# [100.0, 86.41129182198848]

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
algo = ['Random Forest','Linear Regression']
ax.set_title('Accuracy Score ')
ax.bar(algo,accuracy)
plt.show()

# %%
accuracy=[]
accuracy.append(score_dt)
accuracy.append(score_reg)

accuracy
# Out:
# [100.0, 86.41129182198848]

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
algo = [ 'Decision Tree','Linear Regression']
ax.set_title('Accuracy Score ')
ax.bar(algo,accuracy)
plt.show()
